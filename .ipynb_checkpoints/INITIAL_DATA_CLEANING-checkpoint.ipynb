# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies_df = pd.read_csv("data_movie.csv")
movies_df
# Out:
#      movie_id                              title  year     release  \
# 0       m0001                       Pretty Woman  1990  1990-03-22
# 1       m0002            The Godfather: Part III  1990  1990-12-24
# 2       m0003                    Thelma & Louise  1991  1991-05-23
# 3       m0004         Terminator 2: Judgment Day  1991  1991-07-02
# 4       m0005                    Boyz n the Hood  1991  1991-07-11
# ...       ...                                ...   ...         ...
# 1139    m1140                   Ready Player One  2018  2018-03-27
# 1140    m1141                      A Quiet Place  2018  2018-04-03
# 1141    m1142                         Deadpool 2  2018  2018-05-15
# 1142    m1143  Spider-Man: Into the Spider-Verse  2018  2018-12-11
# 1143    m1144                  Avengers: Endgame  2019  2019-04-23
#
#                                                  trivia   mpaa  run_time  \
# 0     A man in a legal but hurtful business needs an...      R       119
# 1     In the midst of trying to legitimize his busin...      R       162
# 2     Two best friends set out on an adventure, but ...      R       130
# 3     A cyborg, identical to the one who failed to k...      R       137
# 4     Follows the lives of three young males living ...      R       112
# ...                                                 ...    ...       ...
# 1139  When the creator of a virtual reality called t...  PG-13       140
# 1140  In a post-apocalyptic world, a family is force...  PG-13        90
# 1141  Foul-mouthed mutant mercenary Wade Wilson a.k....      R       119
# 1142  Teen Miles Morales becomes Spider-Man of his r...     PG       117
# 1143                    After the devastating events of  PG-13       181
#
#                   director              writer              producer  ...  \
# 0           Garry Marshall         J.F. Lawton         Arnon Milchan  ...
# 1     Francis Ford Coppola          Mario Puzo  Francis Ford Coppola  ...
# 2             Ridley Scott       Callie Khouri      Mimi Polk Gitlin  ...
# 3            James Cameron       James Cameron         James Cameron  ...
# 4           John Singleton      John Singleton      Steve Nicolaides  ...
# ...                    ...                 ...                   ...  ...
# 1139      Steven Spielberg            Zak Penn        Donald De Line  ...
# 1140        John Krasinski         Bryan Woods           Michael Bay  ...
# 1141          David Leitch         Rhett Reese         Simon Kinberg  ...
# 1142       Bob Persichetti           Phil Lord              Avi Arad  ...
# 1143         Anthony Russo  Christopher Markus           Kevin Feige  ...
#
#             main_actor_2        main_actor_3       main_actor_4       budget  \
# 0          Julia Roberts     Jason Alexander  Laura San Giacomo   14000000.0
# 1           Diane Keaton         Andy Garcia        Talia Shire   54000000.0
# 2            Geena Davis       Harvey Keitel     Michael Madsen   16500000.0
# 3         Linda Hamilton      Edward Furlong     Robert Patrick  102000000.0
# 4     Laurence Fishburne     Hudhail Al-Amir     Lloyd Avery II    6500000.0
# ...                  ...                 ...                ...          ...
# 1139        Olivia Cooke      Ben Mendelsohn        Lena Waithe  175000000.0
# 1140      John Krasinski  Millicent Simmonds          Noah Jupe   17000000.0
# 1141         Josh Brolin     Morena Baccarin    Julian Dennison  110000000.0
# 1142        Jake Johnson    Hailee Steinfeld     Mahershala Ali   90000000.0
# 1143         Chris Evans        Mark Ruffalo    Chris Hemsworth  356000000.0
#
#          domestic     worldwide    genre_1    genre_2    genre_3 genre_4
# 0     178406268.0  4.634063e+08     Comedy    Romance        NaN     NaN
# 1      66666062.0  1.367661e+08      Crime      Drama        NaN     NaN
# 2      45360915.0  4.543480e+07  Adventure      Crime      Drama     NaN
# 3     205881154.0  5.208848e+08     Action     Sci-Fi        NaN     NaN
# 4      57504069.0  5.752907e+07      Crime      Drama        NaN     NaN
# ...           ...           ...        ...        ...        ...     ...
# 1139  137690172.0  5.828902e+08     Action  Adventure     Sci-Fi     NaN
# 1140  188024361.0  3.409394e+08      Drama     Horror     Sci-Fi     NaN
# 1141  324591735.0  7.857942e+08     Action  Adventure     Comedy  Sci-Fi
# 1142  190241310.0  3.755408e+08     Action  Adventure  Animation  Family
# 1143  858373000.0  2.797801e+09     Action  Adventure      Drama  Sci-Fi
#
# [1144 rows x 22 columns]

# %%
movies_df.describe()
# Out:
#               year     run_time        budget      domestic     worldwide
# count  1144.000000  1144.000000  1.144000e+03  1.144000e+03  1.144000e+03
# mean   2004.451923   115.802448  6.809859e+07  1.035710e+08  2.402453e+08
# std       6.180527    20.624955  5.553107e+07  1.005937e+08  2.770393e+08
# min    1990.000000    77.000000  7.000000e+03  3.047100e+04  3.047100e+04
# 25%    2000.000000   101.000000  2.700000e+07  3.815977e+07  7.143258e+07
# 50%    2004.000000   113.000000  5.200000e+07  7.210151e+07  1.549584e+08
# 75%    2009.000000   128.000000  9.225000e+07  1.335411e+08  2.975740e+08
# max    2019.000000   242.000000  3.560000e+08  9.366622e+08  2.797801e+09

# %% [markdown]
# # Check for duplicates

# %%
movies_df[movies_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, year, release, trivia, mpaa, run_time, director, writer, producer, composer, main_actor_1, main_actor_2, main_actor_3, main_actor_4, budget, domestic, worldwide, genre_1, genre_2, genre_3, genre_4]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# No duplicates

# %% [markdown]
# # Check data types

# %%
movies_df.dtypes
# Out:
# movie_id         object
# title            object
# year              int64
# release          object
# trivia           object
# mpaa             object
# run_time          int64
# director         object
# writer           object
# producer         object
# composer         object
# main_actor_1     object
# main_actor_2     object
# main_actor_3     object
# main_actor_4     object
# budget          float64
# domestic        float64
# worldwide       float64
# genre_1          object
# genre_2          object
# genre_3          object
# genre_4          object
# dtype: object

# %%
# movies_df["release"] = pd.to_datetime(movies_df["release"]) # change to datetime format
# movies_df.dtypes

# %% [markdown]
# # Check for missing values

# %%
movies_df.isnull().sum()
# Out:
# movie_id          0
# title             0
# year              0
# release           0
# trivia            0
# mpaa              0
# run_time          0
# director          0
# writer            0
# producer          0
# composer          0
# main_actor_1      0
# main_actor_2      0
# main_actor_3      0
# main_actor_4      0
# budget            0
# domestic          0
# worldwide         0
# genre_1           0
# genre_2          72
# genre_3         304
# genre_4         725
# dtype: int64

# %% [markdown]
# Key features don't seem to have missing values

# %% [markdown]
# ## Dropping columns with excessive nans: genre_3, genre_4

# %%
movies_df.drop(columns = ["genre_3", "genre_4"], axis = 1, inplace=True)

# %% [markdown]
# # Check for outliers using IQR

# %%
from pandas.api.types import is_numeric_dtype
for col in movies_df.columns:
    if is_numeric_dtype(movies_df[col]) == True:
        series = movies_df[col]
        q1 = series.quantile(0.25)
        q3 = series.quantile(0.75)
        iqr = q3 - q1
        outliers = 0
        for x in series:
            if x > (q3 + (1.5 * iqr)) or x < (q1 - (1.5*iqr)):
                outliers += 1
                
        print(series.name + " has " + str(outliers) + " outliers")
# Out:
# year has 0 outliers
# run_time has 22 outliers
# budget has 45 outliers
# domestic has 76 outliers
# worldwide has 95 outliers

# %% [markdown]
# ## Removing outliers based on IQR

# %%
from pandas.api.types import is_numeric_dtype
for col in movies_df.columns:
    if is_numeric_dtype(movies_df[col]) == True:
        series = movies_df[col]
        q1 = series.quantile(0.25)
        q3 = series.quantile(0.75)
        iqr = q3 - q1
        for x in series:
            if x > (q3 + (1.5 * iqr)) or x < (q1 - (1.5*iqr)):
                series.replace(x, np.nan, inplace=True) # Replace outliers with nan

# %%
movies_df.isnull().sum()
# Out:
# movie_id         0
# title            0
# year             0
# release          0
# trivia           0
# mpaa             0
# run_time        22
# director         0
# writer           0
# producer         0
# composer         0
# main_actor_1     0
# main_actor_2     0
# main_actor_3     0
# main_actor_4     0
# budget          45
# domestic        76
# worldwide       95
# genre_1          0
# genre_2         72
# dtype: int64

# %%
movies_df.shape
# Out:
# (1144, 20)

# %%
movies_df.dropna(axis = 0,inplace=True) # Only rows with more than 2 nan values are dropped

# %%
movies_df.isnull().sum()
# Out:
# movie_id        0
# title           0
# year            0
# release         0
# trivia          0
# mpaa            0
# run_time        0
# director        0
# writer          0
# producer        0
# composer        0
# main_actor_1    0
# main_actor_2    0
# main_actor_3    0
# main_actor_4    0
# budget          0
# domestic        0
# worldwide       0
# genre_1         0
# genre_2         0
# dtype: int64

# %%
movies_df
# Out:
#      movie_id                              title  year     release  \
# 0       m0001                       Pretty Woman  1990  1990-03-22
# 1       m0002            The Godfather: Part III  1990  1990-12-24
# 2       m0003                    Thelma & Louise  1991  1991-05-23
# 3       m0004         Terminator 2: Judgment Day  1991  1991-07-02
# 4       m0005                    Boyz n the Hood  1991  1991-07-11
# ...       ...                                ...   ...         ...
# 1135    m1136                  Blade Runner 2049  2017  2017-10-03
# 1138    m1139                       Annihilation  2018  2018-02-22
# 1139    m1140                   Ready Player One  2018  2018-03-27
# 1140    m1141                      A Quiet Place  2018  2018-04-03
# 1142    m1143  Spider-Man: Into the Spider-Verse  2018  2018-12-11
#
#                                                  trivia   mpaa  run_time  \
# 0     A man in a legal but hurtful business needs an...      R     119.0
# 1     In the midst of trying to legitimize his busin...      R     162.0
# 2     Two best friends set out on an adventure, but ...      R     130.0
# 3     A cyborg, identical to the one who failed to k...      R     137.0
# 4     Follows the lives of three young males living ...      R     112.0
# ...                                                 ...    ...       ...
# 1135  Young Blade Runner K's discovery of a long-bur...      R     164.0
# 1138  A biologist signs up for a dangerous, secret e...      R     115.0
# 1139  When the creator of a virtual reality called t...  PG-13     140.0
# 1140  In a post-apocalyptic world, a family is force...  PG-13      90.0
# 1142  Teen Miles Morales becomes Spider-Man of his r...     PG     117.0
#
#                   director           writer              producer  \
# 0           Garry Marshall      J.F. Lawton         Arnon Milchan
# 1     Francis Ford Coppola       Mario Puzo  Francis Ford Coppola
# 2             Ridley Scott    Callie Khouri      Mimi Polk Gitlin
# 3            James Cameron    James Cameron         James Cameron
# 4           John Singleton   John Singleton      Steve Nicolaides
# ...                    ...              ...                   ...
# 1135      Denis Villeneuve  Hampton Fancher     Broderick Johnson
# 1138          Alex Garland     Alex Garland              Eli Bush
# 1139      Steven Spielberg         Zak Penn        Donald De Line
# 1140        John Krasinski      Bryan Woods           Michael Bay
# 1142       Bob Persichetti        Phil Lord              Avi Arad
#
#                  composer           main_actor_1          main_actor_2  \
# 0     James Newton Howard           Richard Gere         Julia Roberts
# 1         Carmine Coppola              Al Pacino          Diane Keaton
# 2             Hans Zimmer         Susan Sarandon           Geena Davis
# 3             Brad Fiedel  Arnold Schwarzenegger        Linda Hamilton
# 4          Stanley Clarke       Cuba Gooding Jr.    Laurence Fishburne
# ...                   ...                    ...                   ...
# 1135   Benjamin Wallfisch          Harrison Ford          Ryan Gosling
# 1138         Geoff Barrow        Natalie Portman  Jennifer Jason Leigh
# 1139       Alan Silvestri           Tye Sheridan          Olivia Cooke
# 1140       Marco Beltrami            Emily Blunt        John Krasinski
# 1142     Daniel Pemberton          Shameik Moore          Jake Johnson
#
#             main_actor_3       main_actor_4       budget     domestic  \
# 0        Jason Alexander  Laura San Giacomo   14000000.0  178406268.0
# 1            Andy Garcia        Talia Shire   54000000.0   66666062.0
# 2          Harvey Keitel     Michael Madsen   16500000.0   45360915.0
# 3         Edward Furlong     Robert Patrick  102000000.0  205881154.0
# 4        Hudhail Al-Amir     Lloyd Avery II    6500000.0   57504069.0
# ...                  ...                ...          ...          ...
# 1135        Ana de Armas      Dave Bautista  150000000.0   92054159.0
# 1138      Tessa Thompson      Benedict Wong   40000000.0   32732301.0
# 1139      Ben Mendelsohn        Lena Waithe  175000000.0  137690172.0
# 1140  Millicent Simmonds          Noah Jupe   17000000.0  188024361.0
# 1142    Hailee Steinfeld     Mahershala Ali   90000000.0  190241310.0
#
#         worldwide    genre_1    genre_2
# 0     463406268.0     Comedy    Romance
# 1     136766062.0      Crime      Drama
# 2      45434805.0  Adventure      Crime
# 3     520884847.0     Action     Sci-Fi
# 4      57529070.0      Crime      Drama
# ...           ...        ...        ...
# 1135  259239658.0     Action      Drama
# 1138   43070915.0  Adventure      Drama
# 1139  582890172.0     Action  Adventure
# 1140  340939361.0      Drama     Horror
# 1142  375540831.0     Action  Adventure
#
# [947 rows x 20 columns]

# %% [markdown]
# # Viz

# %%
movies_df.describe()
# Out:
#               year    run_time        budget      domestic     worldwide
# count   947.000000  947.000000  9.470000e+02  9.470000e+02  9.470000e+02
# mean   2003.977825  113.417107  5.879206e+07  8.010056e+07  1.734324e+08
# std       5.984347   17.356973  4.240271e+07  5.598592e+07  1.385317e+08
# min    1990.000000   77.000000  7.000000e+03  3.047100e+04  3.047100e+04
# 25%    2000.000000  100.500000  2.600000e+07  3.671334e+07  6.695818e+07
# 50%    2004.000000  112.000000  5.000000e+07  6.545231e+07  1.334409e+08
# 75%    2008.000000  124.000000  8.150000e+07  1.139291e+08  2.394606e+08
# max    2018.000000  168.000000  1.900000e+08  2.676650e+08  6.317462e+08

# %%
from pandas.api.types import is_numeric_dtype
def visualize_srs(series):
    if is_numeric_dtype(series) == True:
        fig, axes = plt.subplots(nrows = 3, ncols =1)
        series.plot(kind = "box", ax = axes[0], figsize = (16,16))
        series.plot(kind = "kde", ax = axes[1], figsize = (16,16))
        series.plot(kind = "hist", ax = axes[2], figsize = (16,16))
    else:
        return

# %%
for col in movies_df.columns:
    visualize_srs(movies_df[col])

# %% [markdown]
# # Merge data sets

# %%
ratings_df = pd.read_csv("data_rating.csv")
ratings_df
# Out:
#         user_id movie_id  rating
# 0        u00001    m0004     4.0
# 1        u00001    m0011     3.5
# 2        u00001    m0024     2.0
# 3        u00001    m0033     4.0
# 4        u00001    m0048     4.0
# ...         ...      ...     ...
# 3363768  u10249    m1138     3.0
# 3363769  u10249    m1139     2.5
# 3363770  u10249    m1140     3.0
# 3363771  u10249    m1141     3.5
# 3363772  u10249    m1142     2.5
#
# [3363773 rows x 3 columns]

# %%
ratings_df.dtypes
# Out:
# user_id      object
# movie_id     object
# rating      float64
# dtype: object

# %%
ratings_df.isnull().sum()
# Out:
# user_id     0
# movie_id    0
# rating      0
# dtype: int64

# %%
merged_df = movies_df.merge(ratings_df, right_on = "movie_id", left_on = "movie_id", how = "right") # Merge based on movie_id
merged_df
# Out:
#         movie_id                       title    year     release  \
# 0          m0004  Terminator 2: Judgment Day  1991.0  1991-07-02
# 1          m0011                     Alien 3  1992.0  1992-05-21
# 2          m0024                         NaN     NaN         NaN
# 3          m0033                         NaN     NaN         NaN
# 4          m0048                         NaN     NaN         NaN
# ...          ...                         ...     ...         ...
# 3363768    m1138                         NaN     NaN         NaN
# 3363769    m1139                Annihilation  2018.0  2018-02-22
# 3363770    m1140            Ready Player One  2018.0  2018-03-27
# 3363771    m1141               A Quiet Place  2018.0  2018-04-03
# 3363772    m1142                         NaN     NaN         NaN
#
#                                                     trivia   mpaa  run_time  \
# 0        A cyborg, identical to the one who failed to k...      R     137.0
# 1        After her last encounter, Ellen Ripley crash-l...      R     114.0
# 2                                                      NaN    NaN       NaN
# 3                                                      NaN    NaN       NaN
# 4                                                      NaN    NaN       NaN
# ...                                                    ...    ...       ...
# 3363768                                                NaN    NaN       NaN
# 3363769  A biologist signs up for a dangerous, secret e...      R     115.0
# 3363770  When the creator of a virtual reality called t...  PG-13     140.0
# 3363771  In a post-apocalyptic world, a family is force...  PG-13      90.0
# 3363772                                                NaN    NaN       NaN
#
#                  director         writer        producer  ...  \
# 0           James Cameron  James Cameron   James Cameron  ...
# 1           David Fincher   Dan O'Bannon  Gordon Carroll  ...
# 2                     NaN            NaN             NaN  ...
# 3                     NaN            NaN             NaN  ...
# 4                     NaN            NaN             NaN  ...
# ...                   ...            ...             ...  ...
# 3363768               NaN            NaN             NaN  ...
# 3363769      Alex Garland   Alex Garland        Eli Bush  ...
# 3363770  Steven Spielberg       Zak Penn  Donald De Line  ...
# 3363771    John Krasinski    Bryan Woods     Michael Bay  ...
# 3363772               NaN            NaN             NaN  ...
#
#                  main_actor_2        main_actor_3    main_actor_4  \
# 0              Linda Hamilton      Edward Furlong  Robert Patrick
# 1           Charles S. Dutton       Charles Dance     Paul McGann
# 2                         NaN                 NaN             NaN
# 3                         NaN                 NaN             NaN
# 4                         NaN                 NaN             NaN
# ...                       ...                 ...             ...
# 3363768                   NaN                 NaN             NaN
# 3363769  Jennifer Jason Leigh      Tessa Thompson   Benedict Wong
# 3363770          Olivia Cooke      Ben Mendelsohn     Lena Waithe
# 3363771        John Krasinski  Millicent Simmonds       Noah Jupe
# 3363772                   NaN                 NaN             NaN
#
#               budget     domestic    worldwide    genre_1    genre_2 user_id  \
# 0        102000000.0  205881154.0  520884847.0     Action     Sci-Fi  u00001
# 1         50000000.0   55473545.0  159814498.0     Action     Horror  u00001
# 2                NaN          NaN          NaN        NaN        NaN  u00001
# 3                NaN          NaN          NaN        NaN        NaN  u00001
# 4                NaN          NaN          NaN        NaN        NaN  u00001
# ...              ...          ...          ...        ...        ...     ...
# 3363768          NaN          NaN          NaN        NaN        NaN  u10249
# 3363769   40000000.0   32732301.0   43070915.0  Adventure      Drama  u10249
# 3363770  175000000.0  137690172.0  582890172.0     Action  Adventure  u10249
# 3363771   17000000.0  188024361.0  340939361.0      Drama     Horror  u10249
# 3363772          NaN          NaN          NaN        NaN        NaN  u10249
#
#         rating
# 0          4.0
# 1          3.5
# 2          2.0
# 3          4.0
# 4          4.0
# ...        ...
# 3363768    3.0
# 3363769    2.5
# 3363770    3.0
# 3363771    3.5
# 3363772    2.5
#
# [3363773 rows x 22 columns]

# %% [markdown]
# Missing values are from ratings for movies that do not exist (movies were removed during the cleaning step)

# %%
merged_df.isnull().sum()
# Out:
# movie_id             0
# title           733682
# year            733682
# release         733682
# trivia          733682
# mpaa            733682
# run_time        733682
# director        733682
# writer          733682
# producer        733682
# composer        733682
# main_actor_1    733682
# main_actor_2    733682
# main_actor_3    733682
# main_actor_4    733682
# budget          733682
# domestic        733682
# worldwide       733682
# genre_1         733682
# genre_2         733682
# user_id              0
# rating               0
# dtype: int64

# %%
merged_df.dropna(inplace=True)

# %%
# merged_df.to_csv("merged_df.csv")

# %% [markdown]
# # Reading Merged Df

# %%
train0df = pd.read_csv(r"C:\Users\WeeKe\Desktop\merged_df.csv")

# %%
train0df.drop(columns = ["Unnamed: 0", "trivia", "release", "movie_id"], inplace=True) # dropping index and unused features

# %%
train0df.head()
# Out:
#                         title    year mpaa  run_time       director  \
# 0  Terminator 2: Judgment Day  1991.0    R     137.0  James Cameron
# 1                     Alien 3  1992.0    R     114.0  David Fincher
# 2             Johnny Mnemonic  1995.0    R      96.0   Robert Longo
# 3                 Judge Dredd  1995.0    R      96.0   Danny Cannon
# 4          The Usual Suspects  1995.0    R     106.0   Bryan Singer
#
#                   writer            producer           composer  \
# 0          James Cameron       James Cameron        Brad Fiedel
# 1           Dan O'Bannon      Gordon Carroll  Elliot Goldenthal
# 2         William Gibson         Don Carmody      Mychael Danna
# 3            John Wagner  Charles Lippincott     Alan Silvestri
# 4  Christopher McQuarrie   Michael McDonnell        John Ottman
#
#             main_actor_1       main_actor_2      main_actor_3  \
# 0  Arnold Schwarzenegger     Linda Hamilton    Edward Furlong
# 1       Sigourney Weaver  Charles S. Dutton     Charles Dance
# 2           Keanu Reeves     Dolph Lundgren        Dina Meyer
# 3     Sylvester Stallone     Armand Assante     Rob Schneider
# 4           Kevin Spacey      Gabriel Byrne  Chazz Palminteri
#
#       main_actor_4       budget     domestic    worldwide genre_1  genre_2  \
# 0   Robert Patrick  102000000.0  205881154.0  520884847.0  Action   Sci-Fi
# 1      Paul McGann   50000000.0   55473545.0  159814498.0  Action   Horror
# 2            Ice-T   26000000.0   19075720.0   19075720.0  Action    Drama
# 3  Jürgen Prochnow   90000000.0   34693481.0  113493481.0  Action    Crime
# 4  Stephen Baldwin    6000000.0   23341568.0   23341568.0   Crime  Mystery
#
#   user_id  rating
# 0  u00001     4.0
# 1  u00001     3.5
# 2  u00001     4.0
# 3  u00001     3.0
# 4  u00001     5.0

# %%
train0df.describe()
# Out:
#                year      run_time        budget      domestic     worldwide  \
# count  2.630091e+06  2.630091e+06  2.630091e+06  2.630091e+06  2.630091e+06
# mean   2.003154e+03  1.152522e+02  6.118144e+07  9.405345e+07  2.051857e+08
# std    5.690170e+00  1.761091e+01  4.328583e+07  6.168248e+07  1.497518e+08
# min    1.990000e+03  7.700000e+01  7.000000e+03  3.047100e+04  3.047100e+04
# 25%    1.999000e+03  1.020000e+02  2.600000e+07  4.422944e+07  8.601306e+07
# 50%    2.003000e+03  1.140000e+02  5.200000e+07  8.007074e+07  1.729897e+08
# 75%    2.007000e+03  1.270000e+02  8.800000e+07  1.323843e+08  2.969388e+08
# max    2.018000e+03  1.680000e+02  1.900000e+08  2.676650e+08  6.317462e+08
#
#              rating
# count  2.630091e+06
# mean   3.306051e+00
# std    1.019609e+00
# min    5.000000e-01
# 25%    3.000000e+00
# 50%    3.500000e+00
# 75%    4.000000e+00
# max    5.000000e+00

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Correlation between numerical features and ratings

# %%
train0df.corr()
# Out:
#                year  run_time    budget  domestic  worldwide    rating
# year       1.000000  0.029333  0.172299  0.078262   0.134185  0.090559
# run_time   0.029333  1.000000  0.286124  0.111963   0.189603  0.128637
# budget     0.172299  0.286124  1.000000  0.514877   0.611363 -0.091040
# domestic   0.078262  0.111963  0.514877  1.000000   0.900361 -0.014907
# worldwide  0.134185  0.189603  0.611363  0.900361   1.000000 -0.002352
# rating     0.090559  0.128637 -0.091040 -0.014907  -0.002352  1.000000

# %%
corr = train0df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Categorizing numerical features (4 categories)
# There are many ways to perform naive Bayes classification (NBC). A common technique in NBC is to recode the feature (variable) values into quartiles, such that values less than the 25th percentile are assigned a 1, 25th to 50th a 2, 50th to 75th a 3 and greater than the 75th percentile a 4. Thus a single object will deposit one count in bin Q1, Q2, Q3, or Q4.

# %%
numeric_features = train0df.select_dtypes(np.number).columns.tolist()
numeric_features.remove("rating") # Remove rating from list of numeric features to convert to categories, since ratings follow it's own rules
numeric_features
# Out:
# ['year', 'run_time', 'budget', 'domestic', 'worldwide']

# %%
train1df = train0df.copy()
for col in numeric_features:
    train1df[col] = pd.qcut(x = train1df[col], q = 4, labels = ["1", "2", "3", "4"]) # Cut and relabel based on quartiles

# %% [markdown]
# # Converting Ratings to categories

# %%
def categorize_ratings(row):
    if row >= 4.0:
        return "TRUE"
    else:
        return "FALSE"

# %%
train1df["rating_cat"] = train1df["rating"].apply(categorize_ratings)

# %%
train1df.drop(columns = ["rating"], inplace=True)

# %%
train1df.head()
# Out:
#                         title year mpaa run_time       director  \
# 0  Terminator 2: Judgment Day    1    R        4  James Cameron
# 1                     Alien 3    1    R        2  David Fincher
# 2             Johnny Mnemonic    1    R        1   Robert Longo
# 3                 Judge Dredd    1    R        1   Danny Cannon
# 4          The Usual Suspects    1    R        2   Bryan Singer
#
#                   writer            producer           composer  \
# 0          James Cameron       James Cameron        Brad Fiedel
# 1           Dan O'Bannon      Gordon Carroll  Elliot Goldenthal
# 2         William Gibson         Don Carmody      Mychael Danna
# 3            John Wagner  Charles Lippincott     Alan Silvestri
# 4  Christopher McQuarrie   Michael McDonnell        John Ottman
#
#             main_actor_1       main_actor_2      main_actor_3  \
# 0  Arnold Schwarzenegger     Linda Hamilton    Edward Furlong
# 1       Sigourney Weaver  Charles S. Dutton     Charles Dance
# 2           Keanu Reeves     Dolph Lundgren        Dina Meyer
# 3     Sylvester Stallone     Armand Assante     Rob Schneider
# 4           Kevin Spacey      Gabriel Byrne  Chazz Palminteri
#
#       main_actor_4 budget domestic worldwide genre_1  genre_2 user_id  \
# 0   Robert Patrick      4        4         4  Action   Sci-Fi  u00001
# 1      Paul McGann      2        2         2  Action   Horror  u00001
# 2            Ice-T      1        1         1  Action    Drama  u00001
# 3  Jürgen Prochnow      4        1         2  Action    Crime  u00001
# 4  Stephen Baldwin      1        1         1   Crime  Mystery  u00001
#
#   rating_cat
# 0       TRUE
# 1      FALSE
# 2       TRUE
# 3      FALSE
# 4       TRUE

# %% [markdown]
# ## Convert all dtypes to Category

# %%
for col in train1df.columns:
    train1df[col] = train1df[col].astype("category")

# %%
train1df.dtypes
# Out:
# title           category
# year            category
# mpaa            category
# run_time        category
# director        category
# writer          category
# producer        category
# composer        category
# main_actor_1    category
# main_actor_2    category
# main_actor_3    category
# main_actor_4    category
# budget          category
# domestic        category
# worldwide       category
# genre_1         category
# genre_2         category
# user_id         category
# rating_cat      category
# dtype: object

# %% [markdown]
# ## Splitting and testing of Model

# %%
from sklearn.model_selection import train_test_split

# %%
X = train1df.iloc[:,0:-1] # X is the features in our dataset
y = train1df.iloc[:,-1]   # y is the Labels in our dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 X = train1df.iloc[:,0:-1] # X is the features in our dataset
#       2 y = train1df.iloc[:,-1]
#
# NameError: name 'train1df' is not defined
